# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
f1 = open('FER.txt', 'r')

# %%
a = []
for line in f1:
            a.append(float(line.rstrip()))

# %%
f1.close()

# %%
#a

# %%
f2 = open('fer_2.txt', 'r')

# %%
b = []
for line in f2:
            b.append(float(line.rstrip()))

# %%
f2.close()

# %%
#b

# %%
x = np.arange(0.01, 0.21, 0.01)

# %%
plt.figure(figsize=(15,10))
plt.ylabel('FER', fontsize = 25)
plt.xlabel('p, probability of error in bit of codeword', fontsize = 25)
plt.grid(True, which="both")
plt.semilogy(x,a, label = 'Single treshhold majority decoding algorithm', lw = 3)
plt.semilogy(x,b, label = 'Multiple treshhold majority decoding algorithm', lw = 3)
plt.legend(prop={'size': 15})
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.show()
